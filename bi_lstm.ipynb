# %%
import os
import pandas as pd
import numpy as np

#Visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Default Size plot 
from pylab import rcParams
rcParams['figure.figsize']=12,5
rcParams['axes.labelsize']=12
rcParams['xtick.labelsize']=12
rcParams['ytick.labelsize']=12

#Handle warning
import warnings
warnings.filterwarnings(action='ignore',category=DeprecationWarning)
warnings.filterwarnings(action='ignore',category=FutureWarning)

#nltk preprocessing modules
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import TweetTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

#regex to find the pattern
import re

#display pandas dataframe columns 
pd.options.display.max_columns = None
pd.set_option('display.max_colwidth', None)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/hirthickkesh/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/hirthickkesh/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
df1 = pd.read_csv(r'/Users/hirthickkesh/Downloads/hate_tweet/train.csv', delimiter=',',engine='python',encoding='utf-8-sig')
test = pd.read_csv(r'/Users/hirthickkesh/Downloads/hate_tweet/test.csv')

# %%
df1
# Out:
#           id  label  \
# 0          1      0
# 1          2      0
# 2          3      0
# 3          4      0
# 4          5      0
# ...      ...    ...
# 31957  31958      0
# 31958  31959      0
# 31959  31960      0
# 31960  31961      1
# 31961  31962      0
#
#                                                                                                                                      tweet
# 0                                    @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1               @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                      bihday your majesty
# 3                                                   #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# ...

# %%
test
# Out:
#           id  \
# 0      31963
# 1      31964
# 2      31965
# 3      31966
# 4      31967
# ...      ...
# 17192  49155
# 17193  49156
# 17194  49157
# 17195  49158
# 17196  49159
#
#                                                                                                                                                    tweet
# 0                                                             #studiolife #aislife #requires #passion #dedication #willpower   to find #newmaterialsâ¦
# 1                                                   @user #white #supremacists want everyone to see the new â  #birdsâ #movie â and hereâs why
# 2                                                                                safe ways to heal your #acne!!    #altwaystoheal #healthy   #healing!!
# 3         is the hp and the cursed child book up for reservations already? if yes, where? if no, when? ððð   #harrypotter #pottermore #favorite
# ...

# %% [markdown]
# Dropping the ID column

# %%
df1.drop('id',axis=1,inplace=True)

# %%
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                                                      tweet
# 0                                    @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1               @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                      bihday your majesty
# 3                                                   #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# ...

# %% [markdown]
# Handling the diacritics in the text, username and http pages

# %%
import unicodedata
def simplify(text):
    try:
        text = unicode(text, 'utf-8')
    except NameError:
        pass
    text = unicodedata.normalize('NFD', text).encode('ascii', 'ignore').decode("utf-8")
    return str(text)

# %%
df1['tweet'] = df1['tweet'].apply(simplify)
df1['tweet'].replace(r'@\w+','',regex=True,inplace=True) #username
df1['tweet'].replace(r'http\S+','',regex=True,inplace=True) #urls

# %%
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                                                      tweet
# 0                                          when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1                           thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                      bihday your majesty
# 3                                                                                   #model   i love u take with u all the time in ur!!!
# ...

# %% [markdown]
# Tokenization using TweetTokenizer

# %%
tt = TweetTokenizer(preserve_case=True) #preserve case is set to true because of preserving the Capital letters.
df1['tweet'] = df1['tweet'].apply(tt.tokenize)

# %% [markdown]
# Removing Stopwords

# %%
nltk.download('stopwords')
stop_words = stopwords.words('english')

additional_list = ['amp','rt','u',"can't",'ur']

for words in additional_list:
    stop_words.append(words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hirthickkesh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(text):
    clean_text = [word for word in text if not word in stop_words]
    return clean_text   
df1['tweet'] = df1['tweet'].apply(remove_stopwords)

# %%
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                                    tweet
# 0                                                    [father, dysfunctional, selfish, drags, kids, dysfunction, ., #run]
# 1                        [thanks, #lyft, credit, use, cause, offer, wheelchair, vans, pdx, ., #disapointed, #getthanked]
# 2                                                                                                      [bihday, majesty]
# 3                                                                                    [#model, love, take, time, !, !, !]
# 4                                                                                  [factsguide, :, society, #motivation]
# ...

# %% [markdown]
# Grammatical Correction and Removing # symbols while retaining the text

# %%
def remove_hashsymbols(text):
    pattern = re.compile(r'#')
    text = ' '.join(text)
    clean_text = re.sub(pattern,'',text)
    return tt.tokenize(clean_text)   
df1['tweet'] = df1['tweet'].apply(remove_hashsymbols)

# %%
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                                  tweet
# 0                                                   [father, dysfunctional, selfish, drags, kids, dysfunction, ., run]
# 1                         [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, ., disapointed, getthanked]
# 2                                                                                                    [bihday, majesty]
# 3                                                                                   [model, love, take, time, !, !, !]
# 4                                                                                 [factsguide, :, society, motivation]
# ...

# %% [markdown]
# Removing single and double length characters

# %%
def rem_shortwords(text):
    lengths = [1,2]
    new_text = ' '.join(text)
    for word in text:
        text = [word for word in tt.tokenize(new_text) if not len(word) in lengths]
        
    return new_text

df1['tweet'] = df1['tweet'].apply(rem_shortwords)

# %%
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                  tweet
# 0                                            father dysfunctional selfish drags kids dysfunction . run
# 1                      thanks lyft credit use cause offer wheelchair vans pdx . disapointed getthanked
# 2                                                                                       bihday majesty
# 3                                                                           model love take time ! ! !
# 4                                                                      factsguide : society motivation
# ...                                                                                                ...
# ...

# %%
df1['tweet'] = df1['tweet'].apply(tt.tokenize)
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                                  tweet
# 0                                                   [father, dysfunctional, selfish, drags, kids, dysfunction, ., run]
# 1                         [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, ., disapointed, getthanked]
# 2                                                                                                    [bihday, majesty]
# 3                                                                                   [model, love, take, time, !, !, !]
# 4                                                                                 [factsguide, :, society, motivation]
# ...

# %% [markdown]
# Removing digits

# %%
def rem_digits(text):
    no_digits = []
    for word in text:
        no_digits.append(re.sub(r'\d','',word))
    return ' '.join(no_digits) 
df1['tweet'] = df1['tweet'].apply(rem_digits)

# %%
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                  tweet
# 0                                            father dysfunctional selfish drags kids dysfunction . run
# 1                      thanks lyft credit use cause offer wheelchair vans pdx . disapointed getthanked
# 2                                                                                       bihday majesty
# 3                                                                           model love take time ! ! !
# 4                                                                      factsguide : society motivation
# ...                                                                                                ...
# ...

# %%
df1['tweet'] = df1['tweet'].apply(tt.tokenize)

# %% [markdown]
# Removing special/non-alpha characters

# %%
def rem_nonalpha(text):
    text = [word for word in text if word.isalpha()]
    return text

df1['tweet'] = df1['tweet'].apply(rem_nonalpha)

# %%
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                               tweet
# 0                                                   [father, dysfunctional, selfish, drags, kids, dysfunction, run]
# 1                         [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, disapointed, getthanked]
# 2                                                                                                 [bihday, majesty]
# 3                                                                                         [model, love, take, time]
# 4                                                                                 [factsguide, society, motivation]
# ...

# %% [markdown]
# Brief EDA

# %%
sns.countplot(x=df1['label'])
plt.title('Hate vs Non Hate Tweet')
plt.grid(True)
plt.show()

label_counts = df1['label'].value_counts()
print("Count of 0s and 1s in 'label':")
print(label_counts)
# Out:
# Count of 0s and 1s in 'label':
# label
# 0    29720
# 1     2242
# Name: count, dtype: int64

# %%
from collections import Counter
results = Counter()
df1['tweet'].apply(results.update)
print(results.most_common(15))
# Out:
# [('love', 2762), ('day', 2319), ('happy', 1679), ('like', 1160), ('time', 1138), ('life', 1124), ('today', 1017), ('new', 994), ('thankful', 947), ('positive', 931), ('get', 919), ('good', 860), ('people', 858), ('bihday', 855), ('one', 784)]

# %%
frequency = nltk.FreqDist(results)
plt.title('Top 15 Most Common Terms')
frequency.plot(15,cumulative=True)
plt.show()

# %%
frequency = nltk.FreqDist(results)
plt.title('Top 15 Most Common Terms')
frequency.plot(15,cumulative=False)
plt.show()

# %%
#check for the null values
df1.isnull().sum()
# Out:
# label    0
# tweet    0
# dtype: int64

# %%
from wordcloud import WordCloud

#For Non-Hate Tweets
non_hate_tweets = ' '.join([' '.join(tweet) for tweet in df1[df1['label'] == 0]['tweet']])
wordcloud_non_hate = WordCloud(width=800, height=400, background_color='white').generate(non_hate_tweets)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_non_hate, interpolation='bilinear')
plt.title('Word Cloud for Non-Hate Tweets')
plt.axis('off')
plt.show()

# %%
#For Hate Tweets
hate_tweets = ' '.join([' '.join(tweet) for tweet in df1[df1['label'] == 1]['tweet']])
wordcloud_hate = WordCloud(width=800, height=400, background_color='white').generate(hate_tweets)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_hate, interpolation='bilinear')
plt.title('Word Cloud for Hate Tweets')
plt.axis('off')
plt.show()

# %%
from nltk import ngrams
from nltk.corpus import stopwords

#Bigrams Analysis
def get_ngrams(text, n=2):
    return list(ngrams(text, n))

stop_words_set = set(stopwords.words('english'))

bigrams = []
for tweet in df1['tweet']:
    filtered_tokens = [word for word in tweet if word.lower() not in stop_words_set]
    bigrams.extend(get_ngrams(filtered_tokens, n=2))

bigram_freq = nltk.FreqDist(bigrams)
print("Most Common Bigrams:")
print(bigram_freq.most_common(10))
# Out:
# Most Common Bigrams:
# [(('thankful', 'positive'), 429), (('positive', 'affirmation'), 352), (('take', 'time'), 336), (('model', 'love'), 326), (('love', 'take'), 325), (('blog', 'silver'), 295), (('silver', 'gold'), 283), (('gold', 'forex'), 263), (('altwaystoheal', 'healthy'), 239), (('fathers', 'day'), 215)]

# %%
#Trigrams Analysis

trigrams = []
for tweet in df1['tweet']:
    filtered_tokens = [word for word in tweet if word.lower() not in stop_words_set]
    trigrams.extend(get_ngrams(filtered_tokens, n=3))

trigram_freq = nltk.FreqDist(trigrams)
print("Most Common Trigrams:")
print(trigram_freq.most_common(10))
# Out:
# Most Common Trigrams:
# [(('model', 'love', 'take'), 325), (('love', 'take', 'time'), 325), (('blog', 'silver', 'gold'), 282), (('silver', 'gold', 'forex'), 263), (('bull', 'dominate', 'bull'), 175), (('dominate', 'bull', 'direct'), 175), (('bull', 'direct', 'whatever'), 175), (('direct', 'whatever', 'want'), 175), (('polar', 'bear', 'climb'), 142), (('bear', 'climb', 'racing'), 142)]

# %%
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                               tweet
# 0                                                   [father, dysfunctional, selfish, drags, kids, dysfunction, run]
# 1                         [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, disapointed, getthanked]
# 2                                                                                                 [bihday, majesty]
# 3                                                                                         [model, love, take, time]
# 4                                                                                 [factsguide, society, motivation]
# ...

# %%
df1['tweet'] = df1['tweet'].apply(lambda x: ' '.join(x))
df1
# Out:
#        label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31957      0
# 31958      0
# 31959      0
# 31960      1
# 31961      0
#
#                                                                                                tweet
# 0                                            father dysfunctional selfish drags kids dysfunction run
# 1                      thanks lyft credit use cause offer wheelchair vans pdx disapointed getthanked
# 2                                                                                     bihday majesty
# 3                                                                               model love take time
# 4                                                                      factsguide society motivation
# ...                                                                                              ...
# ...

# %% [markdown]
# Splitting the dataset int Train and Test for training purpose

# %%
X = df1['tweet']
y = df1['label']

# %%
from sklearn.model_selection import train_test_split
seed = 51
test_size = 0.2 
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=seed,stratify=df1['label']) #use stratify to maintain the imbalance in the dataset
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (25569,) (6393,) (25569,) (6393,)

# %% [markdown]
# Converting the text data into a sparse matrix(vector)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
vectorizer = TfidfVectorizer(max_features=5000)
X_train = vectorizer.fit_transform(X_train)
X_train.shape
# Out:
# (25569, 5000)

# %%
print(type(X_train))  
print(type(X_test))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Bi-LSTM model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score, roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from torchsummary import summary

torch.manual_seed(42)
np.random.seed(42)


smote = SMOTE(sampling_strategy='minority', random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

X_train_tensor = torch.FloatTensor(X_train_resampled.toarray())  
X_test_tensor = torch.FloatTensor(vectorizer.transform(X_test).toarray())

y_train_tensor = torch.LongTensor(y_train_resampled.values)  
y_test_tensor = torch.LongTensor(y_test.values)

train_data = TensorDataset(X_train_tensor, y_train_tensor)
test_data = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)


class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=4):
        super(LSTMModel, self).__init__()

        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=hidden_dim, num_layers=num_layers, 
                            batch_first=True, dropout=0.2, bidirectional=True)

        self.bn = nn.BatchNorm1d(hidden_dim * 2)  

        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)  
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, output_dim)

        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = x.unsqueeze(1)  

        lstm_out, (h_n, c_n) = self.lstm(x)

        out = lstm_out[:, -1, :]

        out = self.bn(out)

        out = self.fc1(out)
        out = self.relu(out)
        out = self.dropout(out)  
        out = self.fc2(out)

        return out

input_dim = X_train_tensor.shape[1]  
hidden_dim = 256  
output_dim = 2  

model = LSTMModel(input_dim, hidden_dim, output_dim)

# print("Model Architecture Summary:")
# summary(model, (X_train_tensor.shape[1], 1))

class_counts = y_train.value_counts()
class_weights = 1. / torch.tensor(class_counts, dtype=torch.float32)
class_weights = class_weights / class_weights.sum() 

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=0.001)

scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

losses = []

num_epochs = 15
for epoch in range(num_epochs):
    model.train()  
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()  
        outputs = model(inputs)  
        loss = criterion(outputs, labels)  
        loss.backward()  
        optimizer.step() 

        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    losses.append(avg_train_loss)  # Store the loss value
    scheduler.step()

    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_train_loss:.4f}')

# Plotting the training loss
plt.figure(figsize=(10, 6))
plt.plot(range(1, num_epochs + 1), losses, label='Training Loss', color='blue')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()


model.eval()  
y_pred = []
y_true = []
y_prob = []  
with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        probs = torch.nn.functional.softmax(outputs, dim=1)  
        _, predicted = torch.max(outputs, 1)  
        y_pred.extend(predicted.cpu().numpy())  
        y_true.extend(labels.cpu().numpy())  
        y_prob.extend(probs.cpu().numpy())  

accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy: {accuracy:.4f}')
print(classification_report(y_true, y_pred, target_names=["Not Hate", "Hate"]))

cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Not Hate", "Hate"], yticklabels=["Not Hate", "Hate"])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

threshold = 0.4
y_pred_thresholded = [1 if prob[1] > threshold else 0 for prob in y_prob]  

accuracy_thresholded = accuracy_score(y_true, y_pred_thresholded)
print(f'Accuracy (Threshold 0.4): {accuracy_thresholded:.4f}')
print(classification_report(y_true, y_pred_thresholded, target_names=["Not Hate", "Hate"]))
# Out:
# Epoch 1/15, Loss: 0.0821
# Epoch 2/15, Loss: 0.0374
# Epoch 3/15, Loss: 0.0292
# Epoch 4/15, Loss: 0.0245
# Epoch 5/15, Loss: 0.0227
# Epoch 6/15, Loss: 0.0158
# Epoch 7/15, Loss: 0.0133
# Epoch 8/15, Loss: 0.0119
# Epoch 9/15, Loss: 0.0108
# Epoch 10/15, Loss: 0.0097
# Epoch 11/15, Loss: 0.0087
# Epoch 12/15, Loss: 0.0083
# Epoch 13/15, Loss: 0.0083
# Epoch 14/15, Loss: 0.0081
# Epoch 15/15, Loss: 0.0082
# Accuracy: 0.9260
#               precision    recall  f1-score   support
#
#     Not Hate       0.97      0.95      0.96      5945
#         Hate       0.48      0.64      0.55       448
#
#     accuracy                           0.93      6393
#    macro avg       0.73      0.79      0.75      6393
# weighted avg       0.94      0.93      0.93      6393
# Accuracy (Threshold 0.4): 0.9243
#               precision    recall  f1-score   support
#
#     Not Hate       0.97      0.95      0.96      5945
#         Hate       0.47      0.64      0.54       448
#
# ...

# %% [markdown]
# Saving the trained model in pkl format

# %%
import torch
import pickle

# torch.save(model.state_dict(), "lstm_model.pth")

with open("bi_lstm_model_1.pkl", "wb") as f:
    pickle.dump(model, f)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %% [markdown]
# Testing the trained model with the test dataset

# %%
import pandas as pd
import torch
from torch.utils.data import DataLoader, TensorDataset

def simplify(text):
    if isinstance(text, str):
        return text.lower()
    return text

def remove_stopwords(tokens):
    stop_words = set(["the", "is", "in", "at", "for", "a", "an"])  
    return [word for word in tokens if word not in stop_words]

def remove_hashsymbols(tokens):
    return [word.replace("#", "") for word in tokens]

def remove_nonalpha(tokens):
    return [word for word in tokens if word.isalpha()]

# Preprocess the tweet text
def preprocess_tweet(tweet):
    tweet = simplify(tweet)
    tweet_tokens = tt.tokenize(tweet)
    tweet_tokens = remove_stopwords(tweet_tokens)
    tweet_tokens = remove_hashsymbols(tweet_tokens)
    tweet_tokens = remove_nonalpha(tweet_tokens)
    return tweet_tokens


test['tweet'] = test['tweet'].apply(preprocess_tweet)
test['tweet'] = test['tweet'].apply(lambda x: " ".join(x))

X_test_new = test['tweet']  
X_test_tensor = torch.FloatTensor(vectorizer.transform(X_test_new).toarray())  

test_data = TensorDataset(X_test_tensor)  
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

with open("bi_lstm_model_1.pkl", "rb") as f:
    model = pickle.load(f)
model.eval()  

y_pred = []

with torch.no_grad():
    for inputs in test_loader:
        outputs = model(inputs[0])  
        _, predicted = torch.max(outputs, 1)  
        y_pred.extend(predicted.cpu().numpy())  

test['predicted_label'] = y_pred

test['id'] = test.get('id', np.arange(len(test)))  

# Save the predictions to a CSV file
test[['id', 'tweet', 'predicted_label']].to_csv('bi_predictions.csv', index=False)

print("Predictions saved to 'bi_predictions.csv'.")
# Out:
# Predictions saved to 'bi_predictions.csv'.

# %%
pred = pd.read_csv('bi_predictions.csv')
pred
# Out:
#           id  \
# 0      31963
# 1      31964
# 2      31965
# 3      31966
# 4      31967
# ...      ...
# 17192  49155
# 17193  49156
# 17194  49157
# 17195  49158
# 17196  49159
#
#                                                                                                                         tweet  \
# 0                                              studiolife aislife requires passion dedication willpower to find newmaterialsâ
# 1                                                white supremacists want everyone to see new â birdsâ movie â and hereâ s why
# 2                                                                   safe ways to heal your acne altwaystoheal healthy healing
# 3              hp and cursed child book up reservations already if yes where if no when ð ð ð harrypotter pottermore favorite
# 4                                            bihday to my amazing hilarious nephew eli ahmir uncle dave loves you and missesâ
# ...

# %%
print(test[test['id'] == 49155])
# Out:
#           id  \
# 17192  49155
#
#                                                                    tweet  \
# 17192  thought factory polarisation trump leadership politics brexit blm
#
#        predicted_label
# 17192                1

# %%
sns.countplot(x=pred['predicted_label'])
plt.title('Count of Hate vs Non Hate Tweet')
plt.grid(True)
plt.show()

# Display the counts of 0 and 1 in the label column
label_counts = pred['predicted_label'].value_counts()
print("Count of 0s and 1s in 'label':")
print(label_counts)
# Out:
# Count of 0s and 1s in 'label':
# predicted_label
# 0    16002
# 1     1195
# Name: count, dtype: int64
